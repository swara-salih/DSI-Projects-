# %% [markdown]
# ## Initial Data Analysis

# %% [markdown]
# # Step 1: Open the sat_scores.csv file. Investigate the data, and answer the questions below.
#
# # AND
#
# # Step 2: Load the data.

# %% [markdown]
# ### 4. Load the data into a list of lists and 5. Print the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sci
import pandas as pd
from scipy import stats
# Remember that for specific functions, the array function in numpy 
# can be useful in listing out the elements in a list (example would
# be for finding the mode.)

with open('./data/sat_scores.csv', 'r') as f:
    data = [i.split(",") for i in f.read().split()]
    print data
# Out:
# [['State', 'Rate', 'Verbal', 'Math'], ['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]

# %%
# Simply writing "data" will present the data in a neater format. 
data
# Out:
# [['State', 'Rate', 'Verbal', 'Math'],
#  ['CT', '82', '509', '510'],
#  ['NJ', '81', '499', '513'],
#  ['MA', '79', '511', '515'],
#  ['NY', '77', '495', '505'],
#  ['NH', '72', '520', '516'],
#  ['RI', '71', '501', '499'],
#  ['PA', '71', '500', '499'],
#  ['VT', '69', '511', '506'],
#  ['ME', '69', '506', '500'],
#  ['VA', '68', '510', '501'],
#  ['DE', '67', '501', '499'],
#  ['MD', '65', '508', '510'],
#  ['NC', '65', '493', '499'],
#  ['GA', '63', '491', '489'],
#  ['IN', '60', '499', '501'],
#  ['SC', '57', '486', '488'],
#  ['DC', '56', '482', '474'],
#  ['OR', '55', '526', '526'],
#  ['FL', '54', '498', '499'],
#  ['WA', '53', '527', '527'],
#  ['TX', '53', '493', '499'],
#  ['HI', '52', '485', '515'],
#  ['AK', '51', '514', '510'],
#  ['CA', '51', '498', '517'],
#  ['AZ', '34', '523', '525'],
#  ['NV', '33', '509', '515'],
#  ['CO', '31', '539', '542'],
#  ['OH', '26', '534', '439'],
#  ['MT', '23', '539', '539'],
#  ['WV', '18', '527', '512'],
#  ['ID', '17', '543', '542'],
#  ['TN', '13', '562', '553'],
#  ['NM', '13', '551', '542'],
#  ['IL', '12', '576', '589'],
#  ['KY', '12', '550', '550'],
#  ['WY', '11', '547', '545'],
#  ['MI', '11', '561', '572'],
#  ['MN', '9', '580', '589'],
#  ['KS', '9', '577', '580'],
#  ['AL', '9', '559', '554'],
#  ['NE', '8', '562', '568'],
#  ['OK', '8', '567', '561'],
#  ['MO', '8', '577', '577'],
#  ['LA', '7', '564', '562'],
#  ['WI', '6', '584', '596'],
#  ['AR', '6', '562', '550'],
#  ['UT', '5', '575', '570'],
#  ['IA', '5', '593', '603'],
#  ['SD', '4', '577', '582'],
#  ['ND', '4', '592', '599'],
#  ['MS', '4', '566', '551'],
#  ['All', '45', '506', '514']]

# %% [markdown]
# ### 1. What does the data describe?
#
# The data describes SAT scores for verbal and math sections in 2001 across the US. It does appear to be complete, except for the issue I'm having with the median score for math. When I ran the median function for sat_scores.math, it returned a value of 521. However, I could not find that value in the dataset. Below are some other observations I made.

# %% [markdown]
# ### 2. Does the data look complete? Are there any obvious issues with the observations?¶

# %% [markdown]
# Overall, the data does look complete, but doing my EDA I noticed that the median value computed for Math, 521, does not actually appear in the list of Math scores. There must be an issue with the data.

# %% [markdown]
# ### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
header = data[0]
data = data[1:]
print(header)
# Out:
# ['State', 'Rate', 'Verbal', 'Math']

# %%
print data
# Out:
# [['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]

# %% [markdown]
# ### 3. Create a data dictionary for the dataset.

# %%
sat_data = {}

for index, column_name in enumerate(header):
   sat_data[column_name] = []
   for row in data:
       sat_data[column_name].append(row[index])
sat_data
# Out:
# {'Math': ['510',
#   '513',
#   '515',
#   '505',
#   '516',
#   '499',
#   '499',
#   '506',
#   '500',
#   '501',
#   '499',
#   '510',
#   '499',
#   '489',
#   '501',
#   '488',
#   '474',
#   '526',
#   '499',
#   '527',
#   '499',
#   '515',
#   '510',
#   '517',
#   '525',
#   '515',
#   '542',
#   '439',
#   '539',
#   '512',
#   '542',
#   '553',
#   '542',
#   '589',
#   '550',
#   '545',
#   '572',
#   '589',
#   '580',
#   '554',
#   '568',
#   '561',
#   '577',
#   '562',
#   '596',
#   '550',
#   '570',
#   '603',
#   '582',
#   '599',
#   '551',
#   '514'],
#  'Rate': ['82',
#   '81',
#   '79',
#   '77',
#   '72',
#   '71',
#   '71',
#   '69',
#   '69',
#   '68',
#   '67',
#   '65',
#   '65',
#   '63',
#   '60',
#   '57',
#   '56',
#   '55',
#   '54',
#   '53',
#   '53',
#   '52',
#   '51',
#   '51',
#   '34',
#   '33',
#   '31',
#   '26',
#   '23',
#   '18',
#   '17',
#   '13',
#   '13',
#   '12',
#   '12',
#   '11',
#   '11',
#   '9',
#   '9',
#   '9',
#   '8',
#   '8',
#   '8',
#   '7',
#   '6',
#   '6',
#   '5',
#   '5',
#   '4',
#   '4',
#   '4',
#   '45'],
#  'State': ['CT',
#   'NJ',
#   'MA',
#   'NY',
#   'NH',
#   'RI',
#   'PA',
#   'VT',
#   'ME',
#   'VA',
#   'DE',
#   'MD',
#   'NC',
#   'GA',
#   'IN',
#   'SC',
#   'DC',
#   'OR',
#   'FL',
#   'WA',
#   'TX',
#   'HI',
#   'AK',
#   'CA',
#   'AZ',
#   'NV',
#   'CO',
#   'OH',
#   'MT',
#   'WV',
#   'ID',
#   'TN',
#   'NM',
#   'IL',
#   'KY',
#   'WY',
#   'MI',
#   'MN',
#   'KS',
#   'AL',
#   'NE',
#   'OK',
#   'MO',
#   'LA',
#   'WI',
#   'AR',
#   'UT',
#   'IA',
#   'SD',
#   'ND',
#   'MS',
#   'All'],
#  'Verbal': ['509',
#   '499',
#   '511',
#   '495',
#   '520',
#   '501',
#   '500',
#   '511',
#   '506',
#   '510',
#   '501',
#   '508',
#   '493',
#   '491',
#   '499',
#   '486',
#   '482',
#   '526',
#   '498',
#   '527',
#   '493',
#   '485',
#   '514',
#   '498',
#   '523',
#   '509',
#   '539',
#   '534',
#   '539',
#   '527',
#   '543',
#   '562',
#   '551',
#   '576',
#   '550',
#   '547',
#   '561',
#   '580',
#   '577',
#   '559',
#   '562',
#   '567',
#   '577',
#   '564',
#   '584',
#   '562',
#   '575',
#   '593',
#   '577',
#   '592',
#   '566',
#   '506']}

# %% [markdown]
# ### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
state_names = sat_data['State']
print state_names
# Out:
# ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All']

# %% [markdown]
# ### 8. Print the types of each column

# %%
type (sat_data['State'][2])
# Out:
# str

# %%
type (sat_data['Math'][2])
# Out:
# str

# %%
type (sat_data['Verbal'][2])
# Out:
# str

# %%
type (sat_data['Rate'][2])
# Out:
# str

# %% [markdown]
# ### 9. Do any types need to be reassigned? If so, go ahead and do it. (was able to do this on Pandas Dataframe below)

# %%
#Math, Verbal, and Rate need to be reassigned to integers. 
for item in sat_data['Math']:
    item = int(item)

# %%
for item in sat_data['Verbal']:
    item = int(item)

# %%
for item in sat_data['Rate']:
    item = int(item)

# %% [markdown]
# ### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
verbal_values = {x:sat_data['Verbal'] for x in state_names}

# %%
math_values = {x:sat_data['Math'] for x in state_names}

# %%
rate_values = {x:sat_data['Rate'] for x in state_names}

# %% [markdown]
# ### 11. Create a dictionary with the values for each of the numeric columns

# %%
#Not sure how to do this.

# %%
for i in range(1,5):
    print i
# Out:
# 1
# 2
# 3
# 4

# %%
print i
# Out:
# 4

# %%
range(1,5)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # # Step 3: Describe the data

# %% [markdown]
# ### 12. Print the min and max of each column

# %%
#Convert to a pandas dataframe to perform functions. 
SAT_scores = pd.DataFrame(sat_data)
SAT_scores
# Out:
#    Math Rate State Verbal
# 0   510   82    CT    509
# 1   513   81    NJ    499
# 2   515   79    MA    511
# 3   505   77    NY    495
# 4   516   72    NH    520
# 5   499   71    RI    501
# 6   499   71    PA    500
# 7   506   69    VT    511
# 8   500   69    ME    506
# 9   501   68    VA    510
# 10  499   67    DE    501
# 11  510   65    MD    508
# 12  499   65    NC    493
# 13  489   63    GA    491
# 14  501   60    IN    499
# 15  488   57    SC    486
# 16  474   56    DC    482
# 17  526   55    OR    526
# 18  499   54    FL    498
# 19  527   53    WA    527
# 20  499   53    TX    493
# 21  515   52    HI    485
# 22  510   51    AK    514
# 23  517   51    CA    498
# 24  525   34    AZ    523
# 25  515   33    NV    509
# 26  542   31    CO    539
# 27  439   26    OH    534
# 28  539   23    MT    539
# 29  512   18    WV    527
# 30  542   17    ID    543
# 31  553   13    TN    562
# 32  542   13    NM    551
# 33  589   12    IL    576
# 34  550   12    KY    550
# 35  545   11    WY    547
# 36  572   11    MI    561
# 37  589    9    MN    580
# 38  580    9    KS    577
# 39  554    9    AL    559
# 40  568    8    NE    562
# 41  561    8    OK    567
# 42  577    8    MO    577
# 43  562    7    LA    564
# 44  596    6    WI    584
# 45  550    6    AR    562
# 46  570    5    UT    575
# 47  603    5    IA    593
# 48  582    4    SD    577
# 49  599    4    ND    592
# 50  551    4    MS    566
# 51  514   45   All    506

# %%
SAT_scores.Verbal.order().value_counts
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# <bound method Series.value_counts of 16    482
# 21    485
# 15    486
# 13    491
# 20    493
# 12    493
# 3     495
# 23    498
# 18    498
# 1     499
# 14    499
# 6     500
# 5     501
# 10    501
# 51    506
# 8     506
# 11    508
# 0     509
# 25    509
# 9     510
# 7     511
# 2     511
# 22    514
# 4     520
# 24    523
# 17    526
# 19    527
# 29    527
# 27    534
# 26    539
# 28    539
# 30    543
# 35    547
# 34    550
# 32    551
# 39    559
# 36    561
# 31    562
# 45    562
# 40    562
# 43    564
# 50    566
# 41    567
# 46    575
# 33    576
# 38    577
# 48    577
# 42    577
# 37    580
# 44    584
# 49    592
# 47    593
# Name: Verbal, dtype: object>

# %%
SAT_scores.Math.order().value_counts
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# <bound method Series.value_counts of 27    439
# 16    474
# 15    488
# 13    489
# 20    499
# 5     499
# 6     499
# 18    499
# 10    499
# 12    499
# 8     500
# 14    501
# 9     501
# 3     505
# 7     506
# 22    510
# 11    510
# 0     510
# 29    512
# 1     513
# 51    514
# 21    515
# 2     515
# 25    515
# 4     516
# 23    517
# 24    525
# 17    526
# 19    527
# 28    539
# 26    542
# 30    542
# 32    542
# 35    545
# 34    550
# 45    550
# 50    551
# 31    553
# 39    554
# 41    561
# 43    562
# 40    568
# 46    570
# 36    572
# 42    577
# 38    580
# 48    582
# 33    589
# 37    589
# 44    596
# 49    599
# 47    603
# Name: Math, dtype: object>

# %%
SAT_scores.Rate.order().value_counts
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: order is deprecated, use sort_values(...)
#   if __name__ == '__main__':
# <bound method Series.value_counts of 36    11
# 35    11
# 34    12
# 33    12
# 32    13
# 31    13
# 30    17
# 29    18
# 28    23
# 27    26
# 26    31
# 25    33
# 24    34
# 49     4
# 48     4
# 50     4
# 51    45
# 46     5
# 47     5
# 22    51
# 23    51
# 21    52
# 19    53
# 20    53
# 18    54
# 17    55
# 16    56
# 15    57
# 44     6
# 45     6
# 14    60
# 13    63
# 12    65
# 11    65
# 10    67
# 9     68
# 8     69
# 7     69
# 43     7
# 5     71
# 6     71
# 4     72
# 3     77
# 2     79
# 40     8
# 41     8
# 42     8
# 1     81
# 0     82
# 38     9
# 37     9
# 39     9
# Name: Rate, dtype: object>

# %% [markdown]
# #### The miniumum rate is 4, found in North Dakota, South Dakota, and Mississippi, and the maximum rate is 82 found in Connecticut.
#
# #### The minimum verbal score is 482 in D.C., and the maximum is 593 in Iowa.
#
# #### The median verbal score is 526 in Oregon.
#
# #### The minimum math score is 439 in Ohio, and the maximum is 603, which is interestingly also in Iowa.
#
# #### The median math score is 521.
#
# #### Iowa has the highest SAT Scores in the country overall.

# %% [markdown]
# ### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
#Standard Deviation function. 
from math import sqrt
def standard_deviation(column):
    num_int = len(column)
    mean = sum(column)/len(column)
    differences = [x - mean for x in column]
    sq_diff = [t ** 2 for t in differences]
    num = sum(sq_diff)
    den = len(column)-1
    var = num/den
    print sqrt(var)

# %%
standard_deviation(SAT_scores['Math'])
# Out:
# 36.0138862107

# %%
standard_deviation(SAT_scores['Verbal'])
# Out:
# 33.2264954517

# %%
standard_deviation(SAT_scores['Rate'])
# Out:
# 27.2946881279

# %%
#Check to see the standard deviations are right. 
print sat_scores.describe()

# %% [markdown]
# ## Mean, Median and Mode in NumPy and SciPy

# %%
# Find the mean, median, and mode for the set of verbal scores and the set of math scores. 
print np.median(sat_scores.verbal)
print np.median(sat_scores.math)
print np.mean(sat_scores)
#Didn't have to convert integers to floats.
#Numpy doesn't have a built in function for mode. However, stats does; 
#its function returns the mode, and how many times the mode appears.
sat_mode = stats.mode(sat_scores)
print sat_mode

# %% [markdown]
# ### The median Verbal SAT score is 526, its mean is approximately 532, and its mode is above its mean at 562 (appears, 3 times).
# ### The median Math SAT score is 521, its mean is 531.5, and its mode is below its mean at 499 (appears 6 times).

# %% [markdown]
# # Step 4: Visualize the data¶

# %%
#Will be using Pandas dataframe for plotting.

# %%
#Have to change the header. 
SAT_scores.columns = SAT_scores.iloc[0]

# %%
SAT_scores

# %%
#Reindex function from Pandas website should do it. 
SAT_scores = SAT_scores.reindex(SAT_scores.index.drop(0))

# %%
SAT_scores
# Out:
#     Math  Rate State  Verbal
# 0    510    82    CT     509
# 1    513    81    NJ     499
# 2    515    79    MA     511
# 3    505    77    NY     495
# 4    516    72    NH     520
# 5    499    71    RI     501
# 6    499    71    PA     500
# 7    506    69    VT     511
# 8    500    69    ME     506
# 9    501    68    VA     510
# 10   499    67    DE     501
# 11   510    65    MD     508
# 12   499    65    NC     493
# 13   489    63    GA     491
# 14   501    60    IN     499
# 15   488    57    SC     486
# 16   474    56    DC     482
# 17   526    55    OR     526
# 18   499    54    FL     498
# 19   527    53    WA     527
# 20   499    53    TX     493
# 21   515    52    HI     485
# 22   510    51    AK     514
# 23   517    51    CA     498
# 24   525    34    AZ     523
# 25   515    33    NV     509
# 26   542    31    CO     539
# 27   439    26    OH     534
# 28   539    23    MT     539
# 29   512    18    WV     527
# 30   542    17    ID     543
# 31   553    13    TN     562
# 32   542    13    NM     551
# 33   589    12    IL     576
# 34   550    12    KY     550
# 35   545    11    WY     547
# 36   572    11    MI     561
# 37   589     9    MN     580
# 38   580     9    KS     577
# 39   554     9    AL     559
# 40   568     8    NE     562
# 41   561     8    OK     567
# 42   577     8    MO     577
# 43   562     7    LA     564
# 44   596     6    WI     584
# 45   550     6    AR     562
# 46   570     5    UT     575
# 47   603     5    IA     593
# 48   582     4    SD     577
# 49   599     4    ND     592
# 50   551     4    MS     566
# 51   514    45   All     506

# %%
SAT_scores.dtypes
# Out:
# Math       int64
# Rate       int64
# State     object
# Verbal     int64
# dtype: object

# %% [markdown]
# ## 19. Plot some scatterplots. BONUS: Use a PyPlot figure to present multiple plots at once.

# %% [markdown]
# ## Scatter Plotting

# %%
sns.regplot(x="Verbal", y="Math", data = SAT_scores)
plt.show()

# %%
sns.regplot(x="Math", y="Verbal", data = SAT_scores)
plt.show()

# %%
sns.regplot(x="Rate", y="Math", data = SAT_scores)
plt.show()

# %%
sns.regplot(x="Rate", y="Verbal", data = SAT_scores)
plt.show()

# %%
SAT_scores.plot(kind='scatter', x='Verbal',y='Math')
plt.show()

# %%
SAT_scores.plot(kind='scatter', x='Math', y='Verbal')
plt.show()

# %%
SAT_scores.plot(kind='scatter', x='Rate', y='Math')
plt.show()

# %% [markdown]
# ### 20. Are there any interesting relationships to note?

# %% [markdown]
# Both Verbal and Math scores are highly correlated with each other, whichever way you plot them, with Math appearing to affect Verbal at a faster rate than the other way around. The integers corresponding to to the Rate column are inversely related with both the Math and Verbal columns, indicating that the higher a state's Math and Verbal scores, the higher the rating (listed starting from 1 as the top) it receives.

# %%
# Before plotting scatter plots, had to convert Pandas values to numeric,
# as seen below.

# %% [markdown]
# ### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
SAT_scores['Verbal'] = SAT_scores['Verbal'].apply(pd.to_numeric)

# %%
SAT_scores['Math'] = SAT_scores['Math'].apply(pd.to_numeric)

# %%
SAT_scores['Rate'] = SAT_scores['Rate'].apply(pd.to_numeric)

# %%
SAT_scores.dtypes
# Out:
# Math       int64
# Rate       int64
# State     object
# Verbal     int64
# dtype: object

# %% [markdown]
# ## 21. Create box plots for each variable.

# %%
#Plot box plots to visualize the distribution of the datasets. 
# Recall the median verbal score is 526, the mean is 532, the max is 593, the min is 482, 
# and the std. deviation is 33.236.
SAT_Scores.Verbal.plot(kind='box')
plt.xlabel('SAT Verbal Scores')
plt.ylabel('Scores')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-14ff59e48cf1> in <module>()
#       2 # Recall the median verbal score is 526, the mean is 532, the max is 593, the min is 482,
#       3 # and the std. deviation is 33.236.
# ----> 4 SAT_Scores.Verbal.plot(kind='box')
#       5 plt.xlabel('SAT Verbal Scores')
#       6 plt.ylabel('Scores')
#
# NameError: name 'SAT_Scores' is not defined

# %% [markdown]
# ## Seaborn Plotting for Box Plots

# %%
sns.boxplot(data = SAT_scores, y=SAT_scores.Verbal, saturation=0.75, width=0.1, fliersize=5)
plt.xlabel('SAT Verbal Scores')
plt.ylabel('Range of Scores')
plt.show()

# %%
sns.boxplot(data = SAT_scores, y=SAT_scores.Math, saturation=0.75, width=0.1, fliersize=5)
plt.xlabel('SAT Math Scores')
plt.ylabel('Range of Scores')
plt.show()

# %%
sns.boxplot(data = SAT_scores, y=SAT_scores.Rate, saturation=0.75, width=0.1, fliersize=5)
plt.xlabel('SAT Rates')
plt.ylabel('Range of Rates')
plt.show()

# %% [markdown]
# ## 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms

# %% [markdown]
# ## Histograms

# %%
SAT_scores.Rate.plot (kind='hist', bins=15)
plt.xlabel('SAT Rates')
plt.ylabel('Frequency')
plt.show()

# %%
SAT_scores.Verbal.plot (kind='hist', bins=15)
plt.xlabel('SAT Verbal Scores')
plt.ylabel('Frequency')
plt.show()

# %%
SAT_scores.Math.plot (kind='hist', bins=15)
plt.xlabel('SAT Math Scores')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 15. Plot the Math distribution

# %%
SAT_scores.Math.plot (kind='hist', bins=15)
plt.xlabel('SAT Math Scores')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 16. Plot the Verbal distribution

# %%
SAT_scores.Verbal.plot (kind='hist', bins=15)
plt.xlabel('SAT Verbal Scores')
plt.ylabel('Frequency')
plt.show()

# %%
SAT_scores.Rate.plot (kind='hist', bins=15)
plt.xlabel('SAT Rates')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 17. What is the typical assumption for data distribution? and 18. Does that distribution hold true for our data?

# %% [markdown]
# #### The typical assumption of data distribution is that it should follow a normal distribution, with standard deviations being relatively equal on both sides of the mean. Neither of the histograms appear to follow a normal distribution, with the Verbal scores in particular following a right/positive skew. But I need to properly check for normal distribution, and find a way the relative distribution onto the histograms. Perhaps Seaborn has a function that can help me with that.

# %% [markdown]
# ## Seaborn Plotting for Histograms and Fitting a Distribution

# %%
# Used seaborn website as guidance: http://seaborn.pydata.org/tutorial/distributions.html
# I used a feature called the 'Kernel Density Estimation" (KDE) to
# visualize a distribution to the data. 
# KDE is an estimator that uses each data point to make an estimate of the distibution and attempts to 
# smooth it out on the histogram. 
# This resulting curve has an area below it equal to one, hence the decimal units for frequency.
sns.distplot(SAT_scores.Verbal, bins=15)
plt.xlabel('SAT Verbal Scores')
plt.ylabel('Frequency (KDE)')
plt.show()

# %%
sns.distplot(SAT_scores.Math, bins=15)
plt.xlabel('SAT Math Scores')
plt.ylabel('Frequency (KDE)')
plt.show()

# %%
sns.distplot(SAT_scores.Rate, bins=15)
plt.xlabel('SAT Rates')
plt.ylabel('Frequency (KDE)')
plt.show()

# %%
sns.kdeplot(SAT_scores.Verbal)
plt.xlabel('SAT Verbal Scores')
plt.ylabel('Frequency (KDE)')
plt.show()

# %%
sns.kdeplot(SAT_scores.Math)
plt.xlabel('SAT Math Scores')
plt.ylabel('Frequency (KDE)')
plt.show()

# %%
sns.kdeplot(SAT_scores.Rate)
plt.xlabel('SAT Rates')
plt.ylabel('Frequency (KDE)')
plt.show()

# %% [markdown]
# ### Both the Verbal and Math scores appear to follow a right/positively skewed distribution.  The Rate score appears to follow something close to a normal distribution, but without a distinct peak--instead it has two.
